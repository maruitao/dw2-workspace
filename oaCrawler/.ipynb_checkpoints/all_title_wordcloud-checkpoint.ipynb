# %%
# -*- coding:utf-8 -*-
import pandas as pd
import jieba
from wordcloud import WordCloud
import sys 
# reload(sys) 
# sys.setdefaultencoding("utf-8")

# %%
df = pd.read_csv('all_data.csv', encoding='utf-8')
df.head
# Out:
# <bound method DataFrame.head of      Unnamed: 0                                              title author  \
# 0             0                      Wotalk在Windows 10中有时无法启动的解决方法     康廷
# 1             1                                 思考：人工智能时代，我们能做点什么？    杨木春
# 2             2                                  2018校招在线考试手机版源码模板    李宏辉
# 3             3                                   2018校招在线考试登录窗口源码    李宏辉
# 4             4         基于openresty使用Lua语言开发，实现动态upstream控制nginx节点    李宏辉
# 5             5                           NAS存储-------NFS与CIFS协议分析    李宏辉
# 6             6                                       2018校园招聘H5源码    李宏辉
# 7             7                          东方通TongWeb5.0配置优化及问题处理PPT    李宏辉
# 8             8                                 关于普通网页微信分享带有缩略图的实现    李宏辉
# 9             9                              sqlserver将查询结果导出Excel     洪柯
# 10           10                                机器学习入门之一图哦也版（一）算法总览    王国栋
# 11           11                    ambari-server搭建分享--ambari搭建 (二)     康龙
# 12           12                       ambari-server搭建分享--准备离线环境(一)     康龙
# 13           13                                  一次关于hadoop平台迁移的分享     康龙
# 14           14                                        上海2017年职称申报    陆晓蕾
# 15           15                                      oracle11g自动备份     路斌
# 16           16                                 关于saas云平台在线问题收集的想法    李宏辉
# 17           17                    从瀚高数据库在Spring事务报错到Spring的事务机制简析     胡正
# 18           18                    关于携程一篇文章“干货 | 图形验证码在携程的实践之路”的杂想    李宏辉
# 19           19                                               项目总结     薄军
# 20           20                                 数据采集工具在项目中的应用总结（上）    邹少怀
# 21           21                                      一次系统性能问题的处理过程     陈雷
# 22           22                                      Coral组件库4.0演示    李宏辉
# 23           23                                        信息发布平台5.0演示    李宏辉
# 24           24                              使用Curator进行Quartz的锁管理     胡正
# 25           25                                        系统管理平台4.0演示    李宏辉
# 26           26                                            达梦数据库手册     许奕
# 27           27                                        2017年4月工作小结     许奕
# 28           28                                   关于信息发布平台用户注册实名遐想    魏爱红
# 29           29                                           人人都是产品经理    杨安荣
# ..          ...                                                ...    ...
# 960         960                               Chrome Packaged Apps     陈雷
# 961         961                    外出登记提交以后,发觉写错日期了,如何修改,或者删除重写申请呢    汪永康
# 962         962         外出登记与工作日志整合在一起，但是选择“日志”类型后，外出登录相关隐藏项没有隐藏完整     陈雷
# 963         963             目前论坛的版块设置过于技术化，有一些市场营销、管理、感想之类的帖子没有地方发    杨安荣
# 964         964                                         中信BBS新增栏目了     张杰
# 965         965                                  新版OA首页增加了“统一管理”栏目     张杰
# 966         966                                          mvc设计模式概述     张杰
# 967         967                                         生日祝福太简单了吧？    孙建兵
# 968         968                                               外出登记    张春岩
# 969         969                                      话说我们公司内网终端的安全    戴旭宏
# 970         970                                主页上的每个版块点了一遍，反馈几个问题    杨安荣
# 971         971                                          FPA性格色彩测试    戴旭宏
# 961  http://180.168.156.212:2262/wecenter/?/article...
# 962  http://180.168.156.212:2262/wecenter/?/article...
# 963  http://180.168.156.212:2262/wecenter/?/article...
# 964  http://180.168.156.212:2262/wecenter/?/article...
# 965  http://180.168.156.212:2262/wecenter/?/article...
# 966  http://180.168.156.212:2262/wecenter/?/article...
# 967  http://180.168.156.212:2262/wecenter/?/article...
# 968  http://180.168.156.212:2262/wecenter/?/article...
# 969  http://180.168.156.212:2262/wecenter/?/article...
# 970  http://180.168.156.212:2262/wecenter/?/article...
# 971  http://180.168.156.212:2262/wecenter/?/article...
# 972  http://180.168.156.212:2262/wecenter/?/article...
# 973  http://180.168.156.212:2262/wecenter/?/article...
# 974  http://180.168.156.212:2262/wecenter/?/article...
# 975  http://180.168.156.212:2262/wecenter/?/article...
# 976  http://180.168.156.212:2262/wecenter/?/article...
# 977  http://180.168.156.212:2262/wecenter/?/article...
# 978  http://180.168.156.212:2262/wecenter/?/article...
# 979  http://180.168.156.212:2262/wecenter/?/article...
# 980  http://180.168.156.212:2262/wecenter/?/article...
# 981  http://180.168.156.212:2262/wecenter/?/article...
# 982  http://180.168.156.212:2262/wecenter/?/article...
# 983  http://180.168.156.212:2262/wecenter/?/article...
# 984  http://180.168.156.212:2262/wecenter/?/article...
# 985  http://180.168.156.212:2262/wecenter/?/article...
# 986  http://180.168.156.212:2262/wecenter/?/article...
# 987  http://180.168.156.212:2262/wecenter/?/article...
# 988  http://180.168.156.212:2262/wecenter/?/article...
# 989  http://180.168.156.212:2262/wecenter/?/article...
#
#                                                content        time
# 0    今天碰到Wotalk无法启动的现象，我的系统是Win10。经过一番设置，找到了解决方法：1、...        6 天前
# 1    1、档案管理机器人： 别人已经开始了，我们是否除了入出库外，可以考虑库房综合，整理盘点，等等...  2017/10/17
# 2    素材源于互联网，改造后的版本适配手机，同时增加了上一题，下一题，以及计时器等相关样式风格ka...  2017/10/13
# 3             该设计来源于互联网，改造后的版本适配移动终端。login-windows.zip  2017/10/13
# 4    实现nginx节点动态控制与监测涉及内容：1、Lua语言2、openresty平台3、ngi...   2017/9/30
# 5    NAS存储-------NFSCIFS协议1、CIFS---Windows系统的文件Micr...   2017/9/30
# 6    动画均为CSS3动画效果JS框架基于zepto，里面使用了两套Slider,一套为PageS...   2017/9/30
# 7    内含配置文档和一份使用手册TongWeb5.0配置优化及问题处理_.pptTongWeb5....   2017/9/30
# 8    新版微信已经不支持非JSSDK的其他自定义分享内容了.....也就是说：想要普通页面链接分享...   2017/9/30
# 9                                                  NaN   2017/6/15
# 10   机器学习入门偏难，包括我在内，很多人总觉得无从下手。所以我准备把自己艰难的入门过程记录下来。...   2017/8/15
# 11   搭建有两种方式,1.采用在线方式下载搭建,2.采用离线环境搭建一.检查仓库是否可用二.安装a...    2017/8/3
# 12   1.下载HDP/HDP-UTLS/ambari-server文件如:在Centos6下tar...    2017/8/3
# 13   此次迁移事件的缘由是因为测试环境的HADOOP部署在VM上,导致大量数据访问操作时IO不够,...   2017/6/25
# 14                                                 NaN   2017/6/20
# 15                                                 NaN   2017/6/14
# 16   今天公司同事在使用vscode编辑器进行编写代码，然后看了下才发现这一年来TypeScrip...   2017/6/14
# 17   系统管理平台4.0小组在使用瀚高数据库的时候，后台报了个错误ERROR:currenttra...    2017/6/8
# 18   携程公众号昨天（6-5）推送了一篇文章“干货|图形验证码在携程的实践之路”，其实我平时基本很...    2017/6/6
# 19                                           工作小结.docx   2017/5/26
# 20   在重要产品追溯项目中，我们要打造一个省级平台，该平台要采集多个城市平台的数据，由于各个城市平...   2017/5/25
# 21   由于应用程序代码存在内存泄露，导致了本次性能故障。顺便也对数据库进行了索引优化，记录一下供以...   2017/5/25
# 22   演示地址:点击打开，如果没有登录请先登录【有功能性问题请在下方留言，也可以直接在产品专区直接...   2017/5/19
# 23   演示地址:点击打开（需要登录），如果没有登录请先登录用户名/密码superadmin/000...   2017/5/19
# 24   在Quartz中，采用的是org.quartz.impl.jdbcjobstore.Sema...   2017/5/18
# 25   系统管理平台4.0版本演示地址:点击打开（需要登录），如果没有登录请先登录用户名/密码sup...   2017/5/18
# 26                              DM7_SQL.pdfDM7_DBA.pdf   2017/5/16
# 27                                                 NaN   2017/5/16
# 28   今天准备到万恶的CSDN上准备下一个东西，突然发现不能下了，如图所示：需要强行手机验证了，关...    2017/5/9
# 29   在人人都想做“产品经理”今天，产品经理到底是干嘛的？需要哪些技能？作为门外汉的我，先贡献一下...   2017/4/26
# ..                                                 ...         ...
# 960  网上看到一篇使用Chrome做离线应用的文章，使用这样的技术貌似可以脱离浏览器，只跟Chro...    2013/5/3
# 961                                                 如题    2013/5/2
# 962  外出登记与工作日志整合在一起，但是选择“日志”类型后，外出登录相关隐藏项没有隐藏完整，还漏了...    2013/5/2
# 963                         还可以增加七嘴八舌板块，反正实名制的，应该不会乱发。    2013/5/2
# 964                         目前新版OA的BBS论坛中增加了最新发帖、最新回复。   2013/4/28
# 965                                  新版OA首页增加了“统一管理”栏目   2013/4/28
# 966  MVC设计模式是一个存在于服务器表达层的模型，它将应用分开，改变应用之间的高度耦合，其中MV...   2013/4/28
# 967               看不到谁给的祝福，也没有祝福的话语，貌似过了本周再也看不到祝福的数字了。   2013/4/28
# 968  哪位大侠给我培训一下，新版OA，怎么登记外出。:?::?::?::?::?::?::?::?...   2013/4/17
# 969  话说~近日在公司内网某服务器上部署了一下企业版的360~对部分终端进行了一下扫描~然后。。。...   2013/4/15
# 970                             先不要急于开发新功能，把现有几个板块搞搞好。   2013/4/15
# 971  用“红、蓝、黄、绿”四色代替人的性格类型，借助一幅幅美妙的图画来解析多变的人生；通过对“性格...    2013/4/7
# 972  人大电子文件研究中心多位档案专家的力作，历经4年完成，目前已经基本定稿ERMS电子文件管理系...    2013/4/2
# 973  该标准目前尚处于表决阶段，所以肯定没有中文版，我好不容易才搞到手，你们当思来之不易啊ISO_...    2013/4/1
# 974  做java开发有几年了---命苦的IT程序猿最近几个月做了十几个mongo数据库的站点项目都...   2013/3/23
# 975  1.下载Windows版本的MongoDB数据库到官方的下载页面下载mongodb的wind...   2013/3/23
# 976  随着互联网web2.0网站的兴起，非关系型的数据库现在成了一个极其热门的新领域，非关系数据库...   2013/3/23
# 977  在struts+hibernate这种结构中，是不应该把Hibernate产生的PO直接传递...   2013/3/23
# 978  我写的一篇文章，希望对spring初学者有所帮助：1、如何学习Spring？你可以通过下列途...   2013/3/23
# 979  很多人对二级缓存都不太了解，或者是有错误的认识，我一直想写一篇文章介绍一下hibernate...   2013/3/23
# 980  Hibernate作为ORM，有一个ORM固有的问题，就是由于为了持久对象的同步，不能够使用...   2013/3/23
# 981  Hibernate入门容易，掌握精通我也不敢自夸。我第一遍看Hibernate文档的时候也觉...   2013/3/23
# 982  该文转自gutyO-RMappingJ2EE的标准是CMPEntityBean，而实际应用中...   2013/3/23
# 983  “为什么Hibernate如此成功！” 这篇文章是GavinKing写的，非常有趣，充分体现...   2013/3/23
# 984                                :):):)路过，一目飘走。。。。。。   2013/3/13
# 985                          快捷方式设置页面显示很缓慢,约等了10几秒才出来.   2013/3/12
# 986       目前给当日寿星送上祝福,不能输入具体的祝福语,仅仅是数字加1,希望可以送上个性的祝福语.   2013/3/12
# 987           报修联系单无法提交!提示:*"分管部门领导/助理审核确认"节点没有合法的审批人！   2013/3/12
# 988                      新增加快捷方式:"财务报销",点击后报错.电子地图.xls   2013/3/12
# 989                      BBS主题发表的输入框太短，稍微超一点的主题会显示不全。。   2013/3/11
#
# [990 rows x 6 columns]>

# %%
def read_stopwords():
    stopwds = []
    with open('chn-stop-words.txt','r') as fh:
        for w in fh :
            stopwds.append(w.strip())
    fh.close()
    return stopwds

# %%
stopwds = read_stopwords()
word_list = []
temp = None

# %%
for val in df['title']:
    temp = jieba.cut(str(val))
    temp = filter(lambda x : len(x) > 1 and x not in stopwds , temp)
    for i in temp :
        if len(i) > 1:
            word_list.append(i.encode('utf-8'))
result = " ".join(word_list)
print type(result)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache c:\users\mart\appdata\local\temp\jieba.cache
# Loading model cost 0.404 seconds.
# Prefix dict has been built succesfully.
# <type 'str'>

# %%
import matplotlib.pyplot as plt
# from scipy.misc import imread
from PIL import Image  
import numpy as np  
# color_mask = imread('bigdata.jpg')
color_mask =  np.array(Image.open("bigdata.jpg"))  
# wordcloud = WordCloud(font_path='simsun.ttf',background_color="white", max_words=500, margin=1, mask=color_mask).generate(result.decode())
wordcloud = WordCloud(font_path='simsun.ttf',background_color="white", max_words=500, margin=1).generate(result.decode())
plt.imshow(wordcloud, interpolation = 'bilinear')

plt.axis('off')
# plt.imshow(alice_coloring, cmap=plt.cm.gray)
plt.show() # 目前词云有英文和中文,因为在调用时传入unicode对象
wordcloud.to_file("title_wordcloud.png")
